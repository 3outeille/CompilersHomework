# %%
# %load gcd.syntax_tree.py

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# %load gcd.syntax_tree.py
#!/usr/bin/env python3
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import svgling
svgling.draw_tree(("type-specifier", ("int")))
svgling.draw_tree(("type-specifier", ("int")))
svgling.draw_tree(("param", ("type-specifier", ("int")), ("u")))
svgling.draw_tree(("param-list", ("param", ("type-specifier", ("int")), ("u"))))
svgling.draw_tree(("type-specifier", ("int")))
svgling.draw_tree(("param", ("type-specifier", ("int")), ("v")))
svgling.draw_tree(("param-list", ("param-list", ("param", ("type-specifier", ("int")), ("u"))), (","), ("param", ("type-specifier", ("int")), ("v"))))
svgling.draw_tree(("params", ("param-list", ("param-list", ("param", ("type-specifier", ("int")), ("u"))), (","), ("param", ("type-specifier", ("int")), ("v")))))
svgling.draw_tree(("epsilon"))
svgling.draw_tree(("local-declarations", ("epsilon")))
svgling.draw_tree(("epsilon"))
svgling.draw_tree(("statement-list", ("epsilon")))
svgling.draw_tree(("var", ("v")))
svgling.draw_tree(("factor", ("var", ("v"))))
svgling.draw_tree(("term", ("factor", ("var", ("v")))))
svgling.draw_tree(("additive-expression", ("term", ("factor", ("var", ("v"))))))
svgling.draw_tree(("relop", ("==")))
svgling.draw_tree(("factor", ("0")))
svgling.draw_tree(("term", ("factor", ("0"))))
svgling.draw_tree(("additive-expression", ("term", ("factor", ("0")))))
svgling.draw_tree(("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("v"))))), ("relop", ("==")), ("additive-expression", ("term", ("factor", ("0"))))))
svgling.draw_tree(("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("v"))))), ("relop", ("==")), ("additive-expression", ("term", ("factor", ("0")))))))
svgling.draw_tree(("var", ("u")))
svgling.draw_tree(("factor", ("var", ("u"))))
svgling.draw_tree(("term", ("factor", ("var", ("u")))))
svgling.draw_tree(("additive-expression", ("term", ("factor", ("var", ("u"))))))
svgling.draw_tree(("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("u")))))))
svgling.draw_tree(("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))))))
svgling.draw_tree(("return-stmt", ("return"), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))))), (";")))
svgling.draw_tree(("statement", ("return-stmt", ("return"), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))))), (";"))))
svgling.draw_tree(("var", ("v")))
svgling.draw_tree(("factor", ("var", ("v"))))
svgling.draw_tree(("term", ("factor", ("var", ("v")))))
svgling.draw_tree(("additive-expression", ("term", ("factor", ("var", ("v"))))))
svgling.draw_tree(("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("v")))))))
svgling.draw_tree(("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("v"))))))))
svgling.draw_tree(("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("v")))))))))
svgling.draw_tree(("var", ("u")))
svgling.draw_tree(("factor", ("var", ("u"))))
svgling.draw_tree(("term", ("factor", ("var", ("u")))))
svgling.draw_tree(("additive-expression", ("term", ("factor", ("var", ("u"))))))
svgling.draw_tree(("addop", ("-")))
svgling.draw_tree(("var", ("u")))
svgling.draw_tree(("factor", ("var", ("u"))))
svgling.draw_tree(("term", ("factor", ("var", ("u")))))
svgling.draw_tree(("mulop", ("/")))
svgling.draw_tree(("var", ("v")))
svgling.draw_tree(("factor", ("var", ("v"))))
svgling.draw_tree(("term", ("term", ("factor", ("var", ("u")))), ("mulop", ("/")), ("factor", ("var", ("v")))))
svgling.draw_tree(("mulop", ("*")))
svgling.draw_tree(("var", ("v")))
svgling.draw_tree(("factor", ("var", ("v"))))
svgling.draw_tree(("term", ("term", ("term", ("factor", ("var", ("u")))), ("mulop", ("/")), ("factor", ("var", ("v")))), ("mulop", ("*")), ("factor", ("var", ("v")))))
svgling.draw_tree(("additive-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))), ("addop", ("-")), ("term", ("term", ("term", ("factor", ("var", ("u")))), ("mulop", ("/")), ("factor", ("var", ("v")))), ("mulop", ("*")), ("factor", ("var", ("v"))))))
svgling.draw_tree(("simple-expression", ("additive-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))), ("addop", ("-")), ("term", ("term", ("term", ("factor", ("var", ("u")))), ("mulop", ("/")), ("factor", ("var", ("v")))), ("mulop", ("*")), ("factor", ("var", ("v")))))))
svgling.draw_tree(("expression", ("simple-expression", ("additive-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))), ("addop", ("-")), ("term", ("term", ("term", ("factor", ("var", ("u")))), ("mulop", ("/")), ("factor", ("var", ("v")))), ("mulop", ("*")), ("factor", ("var", ("v"))))))))
svgling.draw_tree(("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("v")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))), ("addop", ("-")), ("term", ("term", ("term", ("factor", ("var", ("u")))), ("mulop", ("/")), ("factor", ("var", ("v")))), ("mulop", ("*")), ("factor", ("var", ("v")))))))))
svgling.draw_tree(("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("v")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))), ("addop", ("-")), ("term", ("term", ("term", ("factor", ("var", ("u")))), ("mulop", ("/")), ("factor", ("var", ("v")))), ("mulop", ("*")), ("factor", ("var", ("v"))))))))))
svgling.draw_tree(("call", ("gcd"), ("("), ("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("v")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))), ("addop", ("-")), ("term", ("term", ("term", ("factor", ("var", ("u")))), ("mulop", ("/")), ("factor", ("var", ("v")))), ("mulop", ("*")), ("factor", ("var", ("v"))))))))), (")")))
svgling.draw_tree(("factor", ("call", ("gcd"), ("("), ("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("v")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))), ("addop", ("-")), ("term", ("term", ("term", ("factor", ("var", ("u")))), ("mulop", ("/")), ("factor", ("var", ("v")))), ("mulop", ("*")), ("factor", ("var", ("v"))))))))), (")"))))
svgling.draw_tree(("term", ("factor", ("call", ("gcd"), ("("), ("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("v")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))), ("addop", ("-")), ("term", ("term", ("term", ("factor", ("var", ("u")))), ("mulop", ("/")), ("factor", ("var", ("v")))), ("mulop", ("*")), ("factor", ("var", ("v"))))))))), (")")))))
svgling.draw_tree(("additive-expression", ("term", ("factor", ("call", ("gcd"), ("("), ("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("v")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))), ("addop", ("-")), ("term", ("term", ("term", ("factor", ("var", ("u")))), ("mulop", ("/")), ("factor", ("var", ("v")))), ("mulop", ("*")), ("factor", ("var", ("v"))))))))), (")"))))))
svgling.draw_tree(("simple-expression", ("additive-expression", ("term", ("factor", ("call", ("gcd"), ("("), ("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("v")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))), ("addop", ("-")), ("term", ("term", ("term", ("factor", ("var", ("u")))), ("mulop", ("/")), ("factor", ("var", ("v")))), ("mulop", ("*")), ("factor", ("var", ("v"))))))))), (")")))))))
svgling.draw_tree(("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("call", ("gcd"), ("("), ("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("v")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))), ("addop", ("-")), ("term", ("term", ("term", ("factor", ("var", ("u")))), ("mulop", ("/")), ("factor", ("var", ("v")))), ("mulop", ("*")), ("factor", ("var", ("v"))))))))), (")"))))))))
svgling.draw_tree(("return-stmt", ("return"), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("call", ("gcd"), ("("), ("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("v")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))), ("addop", ("-")), ("term", ("term", ("term", ("factor", ("var", ("u")))), ("mulop", ("/")), ("factor", ("var", ("v")))), ("mulop", ("*")), ("factor", ("var", ("v"))))))))), (")"))))))), (";")))
svgling.draw_tree(("statement", ("return-stmt", ("return"), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("call", ("gcd"), ("("), ("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("v")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))), ("addop", ("-")), ("term", ("term", ("term", ("factor", ("var", ("u")))), ("mulop", ("/")), ("factor", ("var", ("v")))), ("mulop", ("*")), ("factor", ("var", ("v"))))))))), (")"))))))), (";"))))
svgling.draw_tree(("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("v"))))), ("relop", ("==")), ("additive-expression", ("term", ("factor", ("0")))))), (")"), ("statement", ("return-stmt", ("return"), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))))), (";"))), ("else"), ("statement", ("return-stmt", ("return"), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("call", ("gcd"), ("("), ("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("v")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))), ("addop", ("-")), ("term", ("term", ("term", ("factor", ("var", ("u")))), ("mulop", ("/")), ("factor", ("var", ("v")))), ("mulop", ("*")), ("factor", ("var", ("v"))))))))), (")"))))))), (";")))))
svgling.draw_tree(("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("v"))))), ("relop", ("==")), ("additive-expression", ("term", ("factor", ("0")))))), (")"), ("statement", ("return-stmt", ("return"), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))))), (";"))), ("else"), ("statement", ("return-stmt", ("return"), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("call", ("gcd"), ("("), ("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("v")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))), ("addop", ("-")), ("term", ("term", ("term", ("factor", ("var", ("u")))), ("mulop", ("/")), ("factor", ("var", ("v")))), ("mulop", ("*")), ("factor", ("var", ("v"))))))))), (")"))))))), (";"))))))
svgling.draw_tree(("statement-list", ("statement-list", ("epsilon")), ("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("v"))))), ("relop", ("==")), ("additive-expression", ("term", ("factor", ("0")))))), (")"), ("statement", ("return-stmt", ("return"), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))))), (";"))), ("else"), ("statement", ("return-stmt", ("return"), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("call", ("gcd"), ("("), ("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("v")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))), ("addop", ("-")), ("term", ("term", ("term", ("factor", ("var", ("u")))), ("mulop", ("/")), ("factor", ("var", ("v")))), ("mulop", ("*")), ("factor", ("var", ("v"))))))))), (")"))))))), (";")))))))
svgling.draw_tree(("compound-stmt", ("{"), ("local-declarations", ("epsilon")), ("statement-list", ("statement-list", ("epsilon")), ("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("v"))))), ("relop", ("==")), ("additive-expression", ("term", ("factor", ("0")))))), (")"), ("statement", ("return-stmt", ("return"), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))))), (";"))), ("else"), ("statement", ("return-stmt", ("return"), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("call", ("gcd"), ("("), ("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("v")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))), ("addop", ("-")), ("term", ("term", ("term", ("factor", ("var", ("u")))), ("mulop", ("/")), ("factor", ("var", ("v")))), ("mulop", ("*")), ("factor", ("var", ("v"))))))))), (")"))))))), (";")))))), ("}")))
svgling.draw_tree(("fun-declaration", ("type-specifier", ("int")), ("gcd"), ("("), ("params", ("param-list", ("param-list", ("param", ("type-specifier", ("int")), ("u"))), (","), ("param", ("type-specifier", ("int")), ("v")))), (")"), ("compound-stmt", ("{"), ("local-declarations", ("epsilon")), ("statement-list", ("statement-list", ("epsilon")), ("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("v"))))), ("relop", ("==")), ("additive-expression", ("term", ("factor", ("0")))))), (")"), ("statement", ("return-stmt", ("return"), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))))), (";"))), ("else"), ("statement", ("return-stmt", ("return"), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("call", ("gcd"), ("("), ("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("v")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))), ("addop", ("-")), ("term", ("term", ("term", ("factor", ("var", ("u")))), ("mulop", ("/")), ("factor", ("var", ("v")))), ("mulop", ("*")), ("factor", ("var", ("v"))))))))), (")"))))))), (";")))))), ("}"))))
svgling.draw_tree(("declaration", ("fun-declaration", ("type-specifier", ("int")), ("gcd"), ("("), ("params", ("param-list", ("param-list", ("param", ("type-specifier", ("int")), ("u"))), (","), ("param", ("type-specifier", ("int")), ("v")))), (")"), ("compound-stmt", ("{"), ("local-declarations", ("epsilon")), ("statement-list", ("statement-list", ("epsilon")), ("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("v"))))), ("relop", ("==")), ("additive-expression", ("term", ("factor", ("0")))))), (")"), ("statement", ("return-stmt", ("return"), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))))), (";"))), ("else"), ("statement", ("return-stmt", ("return"), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("call", ("gcd"), ("("), ("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("v")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))), ("addop", ("-")), ("term", ("term", ("term", ("factor", ("var", ("u")))), ("mulop", ("/")), ("factor", ("var", ("v")))), ("mulop", ("*")), ("factor", ("var", ("v"))))))))), (")"))))))), (";")))))), ("}")))))
svgling.draw_tree(("declaration-list", ("declaration", ("fun-declaration", ("type-specifier", ("int")), ("gcd"), ("("), ("params", ("param-list", ("param-list", ("param", ("type-specifier", ("int")), ("u"))), (","), ("param", ("type-specifier", ("int")), ("v")))), (")"), ("compound-stmt", ("{"), ("local-declarations", ("epsilon")), ("statement-list", ("statement-list", ("epsilon")), ("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("v"))))), ("relop", ("==")), ("additive-expression", ("term", ("factor", ("0")))))), (")"), ("statement", ("return-stmt", ("return"), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))))), (";"))), ("else"), ("statement", ("return-stmt", ("return"), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("call", ("gcd"), ("("), ("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("v")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))), ("addop", ("-")), ("term", ("term", ("term", ("factor", ("var", ("u")))), ("mulop", ("/")), ("factor", ("var", ("v")))), ("mulop", ("*")), ("factor", ("var", ("v"))))))))), (")"))))))), (";")))))), ("}"))))))
svgling.draw_tree(("type-specifier", ("int")))
svgling.draw_tree(("params", ("void")))
svgling.draw_tree(("epsilon"))
svgling.draw_tree(("local-declarations", ("epsilon")))
svgling.draw_tree(("type-specifier", ("int")))
svgling.draw_tree(("var-declaration", ("type-specifier", ("int")), ("x"), (";")))
svgling.draw_tree(("local-declarations", ("local-declarations", ("epsilon")), ("var-declaration", ("type-specifier", ("int")), ("x"), (";"))))
svgling.draw_tree(("type-specifier", ("int")))
svgling.draw_tree(("var-declaration", ("type-specifier", ("int")), ("y"), (";")))
svgling.draw_tree(("local-declarations", ("local-declarations", ("local-declarations", ("epsilon")), ("var-declaration", ("type-specifier", ("int")), ("x"), (";"))), ("var-declaration", ("type-specifier", ("int")), ("y"), (";"))))
svgling.draw_tree(("type-specifier", ("int")))
svgling.draw_tree(("var-declaration", ("type-specifier", ("int")), ("temp"), (";")))
svgling.draw_tree(("local-declarations", ("local-declarations", ("local-declarations", ("local-declarations", ("epsilon")), ("var-declaration", ("type-specifier", ("int")), ("x"), (";"))), ("var-declaration", ("type-specifier", ("int")), ("y"), (";"))), ("var-declaration", ("type-specifier", ("int")), ("temp"), (";"))))
svgling.draw_tree(("epsilon"))
svgling.draw_tree(("statement-list", ("epsilon")))
svgling.draw_tree(("var", ("x")))
svgling.draw_tree(("factor", ("72")))
svgling.draw_tree(("term", ("factor", ("72"))))
svgling.draw_tree(("additive-expression", ("term", ("factor", ("72")))))
svgling.draw_tree(("simple-expression", ("additive-expression", ("term", ("factor", ("72"))))))
svgling.draw_tree(("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("72")))))))
svgling.draw_tree(("expression", ("var", ("x")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("72"))))))))
svgling.draw_tree(("expression-stmt", ("expression", ("var", ("x")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("72"))))))), (";")))
svgling.draw_tree(("statement", ("expression-stmt", ("expression", ("var", ("x")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("72"))))))), (";"))))
svgling.draw_tree(("statement-list", ("statement-list", ("epsilon")), ("statement", ("expression-stmt", ("expression", ("var", ("x")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("72"))))))), (";")))))
svgling.draw_tree(("var", ("y")))
svgling.draw_tree(("factor", ("18")))
svgling.draw_tree(("term", ("factor", ("18"))))
svgling.draw_tree(("additive-expression", ("term", ("factor", ("18")))))
svgling.draw_tree(("simple-expression", ("additive-expression", ("term", ("factor", ("18"))))))
svgling.draw_tree(("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("18")))))))
svgling.draw_tree(("expression", ("var", ("y")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("18"))))))))
svgling.draw_tree(("expression-stmt", ("expression", ("var", ("y")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("18"))))))), (";")))
svgling.draw_tree(("statement", ("expression-stmt", ("expression", ("var", ("y")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("18"))))))), (";"))))
svgling.draw_tree(("statement-list", ("statement-list", ("statement-list", ("epsilon")), ("statement", ("expression-stmt", ("expression", ("var", ("x")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("72"))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("y")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("18"))))))), (";")))))
svgling.draw_tree(("var", ("x")))
svgling.draw_tree(("factor", ("var", ("x"))))
svgling.draw_tree(("term", ("factor", ("var", ("x")))))
svgling.draw_tree(("additive-expression", ("term", ("factor", ("var", ("x"))))))
svgling.draw_tree(("relop", ("<")))
svgling.draw_tree(("var", ("y")))
svgling.draw_tree(("factor", ("var", ("y"))))
svgling.draw_tree(("term", ("factor", ("var", ("y")))))
svgling.draw_tree(("additive-expression", ("term", ("factor", ("var", ("y"))))))
svgling.draw_tree(("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x"))))), ("relop", ("<")), ("additive-expression", ("term", ("factor", ("var", ("y")))))))
svgling.draw_tree(("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x"))))), ("relop", ("<")), ("additive-expression", ("term", ("factor", ("var", ("y"))))))))
svgling.draw_tree(("epsilon"))
svgling.draw_tree(("local-declarations", ("epsilon")))
svgling.draw_tree(("epsilon"))
svgling.draw_tree(("statement-list", ("epsilon")))
svgling.draw_tree(("var", ("temp")))
svgling.draw_tree(("var", ("x")))
svgling.draw_tree(("factor", ("var", ("x"))))
svgling.draw_tree(("term", ("factor", ("var", ("x")))))
svgling.draw_tree(("additive-expression", ("term", ("factor", ("var", ("x"))))))
svgling.draw_tree(("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))
svgling.draw_tree(("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x"))))))))
svgling.draw_tree(("expression", ("var", ("temp")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))))
svgling.draw_tree(("expression-stmt", ("expression", ("var", ("temp")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (";")))
svgling.draw_tree(("statement", ("expression-stmt", ("expression", ("var", ("temp")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (";"))))
svgling.draw_tree(("statement-list", ("statement-list", ("epsilon")), ("statement", ("expression-stmt", ("expression", ("var", ("temp")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (";")))))
svgling.draw_tree(("var", ("x")))
svgling.draw_tree(("var", ("y")))
svgling.draw_tree(("factor", ("var", ("y"))))
svgling.draw_tree(("term", ("factor", ("var", ("y")))))
svgling.draw_tree(("additive-expression", ("term", ("factor", ("var", ("y"))))))
svgling.draw_tree(("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y")))))))
svgling.draw_tree(("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y"))))))))
svgling.draw_tree(("expression", ("var", ("x")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y")))))))))
svgling.draw_tree(("expression-stmt", ("expression", ("var", ("x")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y")))))))), (";")))
svgling.draw_tree(("statement", ("expression-stmt", ("expression", ("var", ("x")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y")))))))), (";"))))
svgling.draw_tree(("statement-list", ("statement-list", ("statement-list", ("epsilon")), ("statement", ("expression-stmt", ("expression", ("var", ("temp")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("x")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y")))))))), (";")))))
svgling.draw_tree(("var", ("y")))
svgling.draw_tree(("var", ("temp")))
svgling.draw_tree(("factor", ("var", ("temp"))))
svgling.draw_tree(("term", ("factor", ("var", ("temp")))))
svgling.draw_tree(("additive-expression", ("term", ("factor", ("var", ("temp"))))))
svgling.draw_tree(("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("temp")))))))
svgling.draw_tree(("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("temp"))))))))
svgling.draw_tree(("expression", ("var", ("y")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("temp")))))))))
svgling.draw_tree(("expression-stmt", ("expression", ("var", ("y")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("temp")))))))), (";")))
svgling.draw_tree(("statement", ("expression-stmt", ("expression", ("var", ("y")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("temp")))))))), (";"))))
svgling.draw_tree(("statement-list", ("statement-list", ("statement-list", ("statement-list", ("epsilon")), ("statement", ("expression-stmt", ("expression", ("var", ("temp")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("x")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y")))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("y")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("temp")))))))), (";")))))
svgling.draw_tree(("compound-stmt", ("{"), ("local-declarations", ("epsilon")), ("statement-list", ("statement-list", ("statement-list", ("statement-list", ("epsilon")), ("statement", ("expression-stmt", ("expression", ("var", ("temp")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("x")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y")))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("y")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("temp")))))))), (";")))), ("}")))
svgling.draw_tree(("statement", ("compound-stmt", ("{"), ("local-declarations", ("epsilon")), ("statement-list", ("statement-list", ("statement-list", ("statement-list", ("epsilon")), ("statement", ("expression-stmt", ("expression", ("var", ("temp")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("x")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y")))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("y")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("temp")))))))), (";")))), ("}"))))
svgling.draw_tree(("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x"))))), ("relop", ("<")), ("additive-expression", ("term", ("factor", ("var", ("y"))))))), (")"), ("statement", ("compound-stmt", ("{"), ("local-declarations", ("epsilon")), ("statement-list", ("statement-list", ("statement-list", ("statement-list", ("epsilon")), ("statement", ("expression-stmt", ("expression", ("var", ("temp")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("x")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y")))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("y")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("temp")))))))), (";")))), ("}")))))
svgling.draw_tree(("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x"))))), ("relop", ("<")), ("additive-expression", ("term", ("factor", ("var", ("y"))))))), (")"), ("statement", ("compound-stmt", ("{"), ("local-declarations", ("epsilon")), ("statement-list", ("statement-list", ("statement-list", ("statement-list", ("epsilon")), ("statement", ("expression-stmt", ("expression", ("var", ("temp")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("x")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y")))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("y")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("temp")))))))), (";")))), ("}"))))))
svgling.draw_tree(("statement-list", ("statement-list", ("statement-list", ("statement-list", ("epsilon")), ("statement", ("expression-stmt", ("expression", ("var", ("x")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("72"))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("y")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("18"))))))), (";")))), ("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x"))))), ("relop", ("<")), ("additive-expression", ("term", ("factor", ("var", ("y"))))))), (")"), ("statement", ("compound-stmt", ("{"), ("local-declarations", ("epsilon")), ("statement-list", ("statement-list", ("statement-list", ("statement-list", ("epsilon")), ("statement", ("expression-stmt", ("expression", ("var", ("temp")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("x")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y")))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("y")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("temp")))))))), (";")))), ("}")))))))
svgling.draw_tree(("var", ("x")))
svgling.draw_tree(("factor", ("var", ("x"))))
svgling.draw_tree(("term", ("factor", ("var", ("x")))))
svgling.draw_tree(("additive-expression", ("term", ("factor", ("var", ("x"))))))
svgling.draw_tree(("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))
svgling.draw_tree(("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x"))))))))
svgling.draw_tree(("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))))
svgling.draw_tree(("var", ("y")))
svgling.draw_tree(("factor", ("var", ("y"))))
svgling.draw_tree(("term", ("factor", ("var", ("y")))))
svgling.draw_tree(("additive-expression", ("term", ("factor", ("var", ("y"))))))
svgling.draw_tree(("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y")))))))
svgling.draw_tree(("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y"))))))))
svgling.draw_tree(("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y")))))))))
svgling.draw_tree(("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y"))))))))))
svgling.draw_tree(("call", ("gcd"), ("("), ("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y"))))))))), (")")))
svgling.draw_tree(("factor", ("call", ("gcd"), ("("), ("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y"))))))))), (")"))))
svgling.draw_tree(("term", ("factor", ("call", ("gcd"), ("("), ("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y"))))))))), (")")))))
svgling.draw_tree(("additive-expression", ("term", ("factor", ("call", ("gcd"), ("("), ("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y"))))))))), (")"))))))
svgling.draw_tree(("simple-expression", ("additive-expression", ("term", ("factor", ("call", ("gcd"), ("("), ("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y"))))))))), (")")))))))
svgling.draw_tree(("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("call", ("gcd"), ("("), ("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y"))))))))), (")"))))))))
svgling.draw_tree(("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("call", ("gcd"), ("("), ("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y"))))))))), (")"))))))), (";")))
svgling.draw_tree(("statement", ("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("call", ("gcd"), ("("), ("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y"))))))))), (")"))))))), (";"))))
svgling.draw_tree(("statement-list", ("statement-list", ("statement-list", ("statement-list", ("statement-list", ("epsilon")), ("statement", ("expression-stmt", ("expression", ("var", ("x")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("72"))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("y")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("18"))))))), (";")))), ("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x"))))), ("relop", ("<")), ("additive-expression", ("term", ("factor", ("var", ("y"))))))), (")"), ("statement", ("compound-stmt", ("{"), ("local-declarations", ("epsilon")), ("statement-list", ("statement-list", ("statement-list", ("statement-list", ("epsilon")), ("statement", ("expression-stmt", ("expression", ("var", ("temp")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("x")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y")))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("y")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("temp")))))))), (";")))), ("}")))))), ("statement", ("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("call", ("gcd"), ("("), ("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y"))))))))), (")"))))))), (";")))))
svgling.draw_tree(("factor", ("0")))
svgling.draw_tree(("term", ("factor", ("0"))))
svgling.draw_tree(("additive-expression", ("term", ("factor", ("0")))))
svgling.draw_tree(("simple-expression", ("additive-expression", ("term", ("factor", ("0"))))))
svgling.draw_tree(("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("0")))))))
svgling.draw_tree(("return-stmt", ("return"), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("0")))))), (";")))
svgling.draw_tree(("statement", ("return-stmt", ("return"), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("0")))))), (";"))))
svgling.draw_tree(("statement-list", ("statement-list", ("statement-list", ("statement-list", ("statement-list", ("statement-list", ("epsilon")), ("statement", ("expression-stmt", ("expression", ("var", ("x")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("72"))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("y")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("18"))))))), (";")))), ("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x"))))), ("relop", ("<")), ("additive-expression", ("term", ("factor", ("var", ("y"))))))), (")"), ("statement", ("compound-stmt", ("{"), ("local-declarations", ("epsilon")), ("statement-list", ("statement-list", ("statement-list", ("statement-list", ("epsilon")), ("statement", ("expression-stmt", ("expression", ("var", ("temp")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("x")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y")))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("y")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("temp")))))))), (";")))), ("}")))))), ("statement", ("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("call", ("gcd"), ("("), ("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y"))))))))), (")"))))))), (";")))), ("statement", ("return-stmt", ("return"), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("0")))))), (";")))))
svgling.draw_tree(("compound-stmt", ("{"), ("local-declarations", ("local-declarations", ("local-declarations", ("local-declarations", ("epsilon")), ("var-declaration", ("type-specifier", ("int")), ("x"), (";"))), ("var-declaration", ("type-specifier", ("int")), ("y"), (";"))), ("var-declaration", ("type-specifier", ("int")), ("temp"), (";"))), ("statement-list", ("statement-list", ("statement-list", ("statement-list", ("statement-list", ("statement-list", ("epsilon")), ("statement", ("expression-stmt", ("expression", ("var", ("x")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("72"))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("y")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("18"))))))), (";")))), ("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x"))))), ("relop", ("<")), ("additive-expression", ("term", ("factor", ("var", ("y"))))))), (")"), ("statement", ("compound-stmt", ("{"), ("local-declarations", ("epsilon")), ("statement-list", ("statement-list", ("statement-list", ("statement-list", ("epsilon")), ("statement", ("expression-stmt", ("expression", ("var", ("temp")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("x")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y")))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("y")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("temp")))))))), (";")))), ("}")))))), ("statement", ("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("call", ("gcd"), ("("), ("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y"))))))))), (")"))))))), (";")))), ("statement", ("return-stmt", ("return"), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("0")))))), (";")))), ("}")))
svgling.draw_tree(("fun-declaration", ("type-specifier", ("int")), ("main"), ("("), ("params", ("void")), (")"), ("compound-stmt", ("{"), ("local-declarations", ("local-declarations", ("local-declarations", ("local-declarations", ("epsilon")), ("var-declaration", ("type-specifier", ("int")), ("x"), (";"))), ("var-declaration", ("type-specifier", ("int")), ("y"), (";"))), ("var-declaration", ("type-specifier", ("int")), ("temp"), (";"))), ("statement-list", ("statement-list", ("statement-list", ("statement-list", ("statement-list", ("statement-list", ("epsilon")), ("statement", ("expression-stmt", ("expression", ("var", ("x")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("72"))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("y")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("18"))))))), (";")))), ("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x"))))), ("relop", ("<")), ("additive-expression", ("term", ("factor", ("var", ("y"))))))), (")"), ("statement", ("compound-stmt", ("{"), ("local-declarations", ("epsilon")), ("statement-list", ("statement-list", ("statement-list", ("statement-list", ("epsilon")), ("statement", ("expression-stmt", ("expression", ("var", ("temp")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("x")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y")))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("y")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("temp")))))))), (";")))), ("}")))))), ("statement", ("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("call", ("gcd"), ("("), ("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y"))))))))), (")"))))))), (";")))), ("statement", ("return-stmt", ("return"), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("0")))))), (";")))), ("}"))))
svgling.draw_tree(("declaration", ("fun-declaration", ("type-specifier", ("int")), ("main"), ("("), ("params", ("void")), (")"), ("compound-stmt", ("{"), ("local-declarations", ("local-declarations", ("local-declarations", ("local-declarations", ("epsilon")), ("var-declaration", ("type-specifier", ("int")), ("x"), (";"))), ("var-declaration", ("type-specifier", ("int")), ("y"), (";"))), ("var-declaration", ("type-specifier", ("int")), ("temp"), (";"))), ("statement-list", ("statement-list", ("statement-list", ("statement-list", ("statement-list", ("statement-list", ("epsilon")), ("statement", ("expression-stmt", ("expression", ("var", ("x")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("72"))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("y")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("18"))))))), (";")))), ("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x"))))), ("relop", ("<")), ("additive-expression", ("term", ("factor", ("var", ("y"))))))), (")"), ("statement", ("compound-stmt", ("{"), ("local-declarations", ("epsilon")), ("statement-list", ("statement-list", ("statement-list", ("statement-list", ("epsilon")), ("statement", ("expression-stmt", ("expression", ("var", ("temp")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("x")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y")))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("y")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("temp")))))))), (";")))), ("}")))))), ("statement", ("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("call", ("gcd"), ("("), ("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y"))))))))), (")"))))))), (";")))), ("statement", ("return-stmt", ("return"), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("0")))))), (";")))), ("}")))))
svgling.draw_tree(("declaration-list", ("declaration-list", ("declaration", ("fun-declaration", ("type-specifier", ("int")), ("gcd"), ("("), ("params", ("param-list", ("param-list", ("param", ("type-specifier", ("int")), ("u"))), (","), ("param", ("type-specifier", ("int")), ("v")))), (")"), ("compound-stmt", ("{"), ("local-declarations", ("epsilon")), ("statement-list", ("statement-list", ("epsilon")), ("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("v"))))), ("relop", ("==")), ("additive-expression", ("term", ("factor", ("0")))))), (")"), ("statement", ("return-stmt", ("return"), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))))), (";"))), ("else"), ("statement", ("return-stmt", ("return"), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("call", ("gcd"), ("("), ("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("v")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))), ("addop", ("-")), ("term", ("term", ("term", ("factor", ("var", ("u")))), ("mulop", ("/")), ("factor", ("var", ("v")))), ("mulop", ("*")), ("factor", ("var", ("v"))))))))), (")"))))))), (";")))))), ("}"))))), ("declaration", ("fun-declaration", ("type-specifier", ("int")), ("main"), ("("), ("params", ("void")), (")"), ("compound-stmt", ("{"), ("local-declarations", ("local-declarations", ("local-declarations", ("local-declarations", ("epsilon")), ("var-declaration", ("type-specifier", ("int")), ("x"), (";"))), ("var-declaration", ("type-specifier", ("int")), ("y"), (";"))), ("var-declaration", ("type-specifier", ("int")), ("temp"), (";"))), ("statement-list", ("statement-list", ("statement-list", ("statement-list", ("statement-list", ("statement-list", ("epsilon")), ("statement", ("expression-stmt", ("expression", ("var", ("x")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("72"))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("y")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("18"))))))), (";")))), ("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x"))))), ("relop", ("<")), ("additive-expression", ("term", ("factor", ("var", ("y"))))))), (")"), ("statement", ("compound-stmt", ("{"), ("local-declarations", ("epsilon")), ("statement-list", ("statement-list", ("statement-list", ("statement-list", ("epsilon")), ("statement", ("expression-stmt", ("expression", ("var", ("temp")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("x")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y")))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("y")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("temp")))))))), (";")))), ("}")))))), ("statement", ("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("call", ("gcd"), ("("), ("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y"))))))))), (")"))))))), (";")))), ("statement", ("return-stmt", ("return"), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("0")))))), (";")))), ("}"))))))
svgling.draw_tree(("declaration-list", ("declaration-list", ("declaration", ("fun-declaration", ("type-specifier", ("int")), ("gcd"), ("("), ("params", ("param-list", ("param-list", ("param", ("type-specifier", ("int")), ("u"))), (","), ("param", ("type-specifier", ("int")), ("v")))), (")"), ("compound-stmt", ("{"), ("local-declarations", ("epsilon")), ("statement-list", ("statement-list", ("epsilon")), ("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("v"))))), ("relop", ("==")), ("additive-expression", ("term", ("factor", ("0")))))), (")"), ("statement", ("return-stmt", ("return"), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))))), (";"))), ("else"), ("statement", ("return-stmt", ("return"), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("call", ("gcd"), ("("), ("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("v")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("additive-expression", ("term", ("factor", ("var", ("u"))))), ("addop", ("-")), ("term", ("term", ("term", ("factor", ("var", ("u")))), ("mulop", ("/")), ("factor", ("var", ("v")))), ("mulop", ("*")), ("factor", ("var", ("v"))))))))), (")"))))))), (";")))))), ("}"))))), ("declaration", ("fun-declaration", ("type-specifier", ("int")), ("main"), ("("), ("params", ("void")), (")"), ("compound-stmt", ("{"), ("local-declarations", ("local-declarations", ("local-declarations", ("local-declarations", ("epsilon")), ("var-declaration", ("type-specifier", ("int")), ("x"), (";"))), ("var-declaration", ("type-specifier", ("int")), ("y"), (";"))), ("var-declaration", ("type-specifier", ("int")), ("temp"), (";"))), ("statement-list", ("statement-list", ("statement-list", ("statement-list", ("statement-list", ("statement-list", ("epsilon")), ("statement", ("expression-stmt", ("expression", ("var", ("x")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("72"))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("y")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("18"))))))), (";")))), ("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x"))))), ("relop", ("<")), ("additive-expression", ("term", ("factor", ("var", ("y"))))))), (")"), ("statement", ("compound-stmt", ("{"), ("local-declarations", ("epsilon")), ("statement-list", ("statement-list", ("statement-list", ("statement-list", ("epsilon")), ("statement", ("expression-stmt", ("expression", ("var", ("temp")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("x")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y")))))))), (";")))), ("statement", ("expression-stmt", ("expression", ("var", ("y")), ("="), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("temp")))))))), (";")))), ("}")))))), ("statement", ("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("call", ("gcd"), ("("), ("args", ("arg-list", ("arg-list", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("x")))))))), (","), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("y"))))))))), (")"))))))), (";")))), ("statement", ("return-stmt", ("return"), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("0")))))), (";")))), ("}")))))).get_svg().saveas("gcdtree.svg")
# Out:
# TreeLayout(('type-specifier', 'int'))
# TreeLayout(('type-specifier', 'int'))
# TreeLayout(('param', ('type-specifier', 'int'), 'u'))
# TreeLayout(('param-list', ('param', ('type-specifier', 'int'), 'u')))
# TreeLayout(('type-specifier', 'int'))
# TreeLayout(('param', ('type-specifier', 'int'), 'v'))
# TreeLayout(('param-list', ('param-list', ('param', ('type-specifier', 'int'), 'u')), ',', ('param', ('type-specifier', 'int'), 'v')))
# TreeLayout(('params', ('param-list', ('param-list', ('param', ('type-specifier', 'int'), 'u')), ',', ('param', ('type-specifier', 'int'), 'v'))))
# TreeLayout('epsilon')
# TreeLayout(('local-declarations', 'epsilon'))
# TreeLayout('epsilon')
# TreeLayout(('statement-list', 'epsilon'))
# TreeLayout(('var', 'v'))
# TreeLayout(('factor', ('var', 'v')))
# TreeLayout(('term', ('factor', ('var', 'v'))))
# TreeLayout(('additive-expression', ('term', ('factor', ('var', 'v')))))
# TreeLayout(('relop', '=='))
# TreeLayout(('factor', '0'))
# ...

# %%
# %load if_test.syntax_tree.py
#!/usr/bin/env python3
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import svgling
svgling.draw_tree(("type-specifier", ("void")))
svgling.draw_tree(("params", ("void")))
svgling.draw_tree(("epsilon"))
svgling.draw_tree(("local-declarations", ("epsilon")))
svgling.draw_tree(("epsilon"))
svgling.draw_tree(("statement-list", ("epsilon")))
svgling.draw_tree(("var", ("a")))
svgling.draw_tree(("factor", ("var", ("a"))))
svgling.draw_tree(("term", ("factor", ("var", ("a")))))
svgling.draw_tree(("additive-expression", ("term", ("factor", ("var", ("a"))))))
svgling.draw_tree(("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("a")))))))
svgling.draw_tree(("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("a"))))))))
svgling.draw_tree(("var", ("b")))
svgling.draw_tree(("factor", ("var", ("b"))))
svgling.draw_tree(("term", ("factor", ("var", ("b")))))
svgling.draw_tree(("additive-expression", ("term", ("factor", ("var", ("b"))))))
svgling.draw_tree(("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("b")))))))
svgling.draw_tree(("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("b"))))))))
svgling.draw_tree(("var", ("a")))
svgling.draw_tree(("factor", ("var", ("a"))))
svgling.draw_tree(("term", ("factor", ("var", ("a")))))
svgling.draw_tree(("additive-expression", ("term", ("factor", ("var", ("a"))))))
svgling.draw_tree(("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("a")))))))
svgling.draw_tree(("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("a"))))))))
svgling.draw_tree(("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("a"))))))), (";")))
svgling.draw_tree(("statement", ("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("a"))))))), (";"))))
svgling.draw_tree(("var", ("b")))
svgling.draw_tree(("factor", ("var", ("b"))))
svgling.draw_tree(("term", ("factor", ("var", ("b")))))
svgling.draw_tree(("additive-expression", ("term", ("factor", ("var", ("b"))))))
svgling.draw_tree(("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("b")))))))
svgling.draw_tree(("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("b"))))))))
svgling.draw_tree(("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("b"))))))), (";")))
svgling.draw_tree(("statement", ("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("b"))))))), (";"))))
svgling.draw_tree(("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("b"))))))), (")"), ("statement", ("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("a"))))))), (";"))), ("else"), ("statement", ("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("b"))))))), (";")))))
svgling.draw_tree(("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("b"))))))), (")"), ("statement", ("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("a"))))))), (";"))), ("else"), ("statement", ("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("b"))))))), (";"))))))
svgling.draw_tree(("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("a"))))))), (")"), ("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("b"))))))), (")"), ("statement", ("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("a"))))))), (";"))), ("else"), ("statement", ("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("b"))))))), (";")))))))
svgling.draw_tree(("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("a"))))))), (")"), ("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("b"))))))), (")"), ("statement", ("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("a"))))))), (";"))), ("else"), ("statement", ("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("b"))))))), (";"))))))))
svgling.draw_tree(("statement-list", ("statement-list", ("epsilon")), ("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("a"))))))), (")"), ("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("b"))))))), (")"), ("statement", ("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("a"))))))), (";"))), ("else"), ("statement", ("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("b"))))))), (";")))))))))
svgling.draw_tree(("return-stmt", ("return"), (";")))
svgling.draw_tree(("statement", ("return-stmt", ("return"), (";"))))
svgling.draw_tree(("statement-list", ("statement-list", ("statement-list", ("epsilon")), ("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("a"))))))), (")"), ("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("b"))))))), (")"), ("statement", ("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("a"))))))), (";"))), ("else"), ("statement", ("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("b"))))))), (";")))))))), ("statement", ("return-stmt", ("return"), (";")))))
svgling.draw_tree(("compound-stmt", ("{"), ("local-declarations", ("epsilon")), ("statement-list", ("statement-list", ("statement-list", ("epsilon")), ("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("a"))))))), (")"), ("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("b"))))))), (")"), ("statement", ("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("a"))))))), (";"))), ("else"), ("statement", ("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("b"))))))), (";")))))))), ("statement", ("return-stmt", ("return"), (";")))), ("}")))
svgling.draw_tree(("fun-declaration", ("type-specifier", ("void")), ("fun"), ("("), ("params", ("void")), (")"), ("compound-stmt", ("{"), ("local-declarations", ("epsilon")), ("statement-list", ("statement-list", ("statement-list", ("epsilon")), ("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("a"))))))), (")"), ("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("b"))))))), (")"), ("statement", ("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("a"))))))), (";"))), ("else"), ("statement", ("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("b"))))))), (";")))))))), ("statement", ("return-stmt", ("return"), (";")))), ("}"))))
svgling.draw_tree(("declaration", ("fun-declaration", ("type-specifier", ("void")), ("fun"), ("("), ("params", ("void")), (")"), ("compound-stmt", ("{"), ("local-declarations", ("epsilon")), ("statement-list", ("statement-list", ("statement-list", ("epsilon")), ("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("a"))))))), (")"), ("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("b"))))))), (")"), ("statement", ("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("a"))))))), (";"))), ("else"), ("statement", ("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("b"))))))), (";")))))))), ("statement", ("return-stmt", ("return"), (";")))), ("}")))))
svgling.draw_tree(("declaration-list", ("declaration", ("fun-declaration", ("type-specifier", ("void")), ("fun"), ("("), ("params", ("void")), (")"), ("compound-stmt", ("{"), ("local-declarations", ("epsilon")), ("statement-list", ("statement-list", ("statement-list", ("epsilon")), ("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("a"))))))), (")"), ("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("b"))))))), (")"), ("statement", ("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("a"))))))), (";"))), ("else"), ("statement", ("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("b"))))))), (";")))))))), ("statement", ("return-stmt", ("return"), (";")))), ("}"))))))
svgling.draw_tree(("declaration-list", ("declaration", ("fun-declaration", ("type-specifier", ("void")), ("fun"), ("("), ("params", ("void")), (")"), ("compound-stmt", ("{"), ("local-declarations", ("epsilon")), ("statement-list", ("statement-list", ("statement-list", ("epsilon")), ("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("a"))))))), (")"), ("statement", ("selection-stmt", ("if"), ("("), ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("b"))))))), (")"), ("statement", ("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("a"))))))), (";"))), ("else"), ("statement", ("expression-stmt", ("expression", ("simple-expression", ("additive-expression", ("term", ("factor", ("var", ("b"))))))), (";")))))))), ("statement", ("return-stmt", ("return"), (";")))), ("}"))))))
# Out:
# TreeLayout(('type-specifier', 'void'))
# TreeLayout(('params', 'void'))
# TreeLayout('epsilon')
# TreeLayout(('local-declarations', 'epsilon'))
# TreeLayout('epsilon')
# TreeLayout(('statement-list', 'epsilon'))
# TreeLayout(('var', 'a'))
# TreeLayout(('factor', ('var', 'a')))
# TreeLayout(('term', ('factor', ('var', 'a'))))
# TreeLayout(('additive-expression', ('term', ('factor', ('var', 'a')))))
# TreeLayout(('simple-expression', ('additive-expression', ('term', ('factor', ('var', 'a'))))))
# TreeLayout(('expression', ('simple-expression', ('additive-expression', ('term', ('factor', ('var', 'a')))))))
# TreeLayout(('var', 'b'))
# TreeLayout(('factor', ('var', 'b')))
# TreeLayout(('term', ('factor', ('var', 'b'))))
# TreeLayout(('additive-expression', ('term', ('factor', ('var', 'b')))))
# TreeLayout(('simple-expression', ('additive-expression', ('term', ('factor', ('var', 'b'))))))
# ...

# %%
# from the last tree we can see the shift-reduce conflict is solved by give them an order
